# %%
import numpy as np                        # Importing necessary libraries.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv")
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.head()     # Displays first 5 rows from the dataset.
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail()           # Displays last 5 rows from the dataset.
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
df.sample()           # Displays randomly any 1 row.
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 5385     11.0  29-07-2016          27.7          23.0    70.817207
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  \
# 5385    94.686462         30.574987         25.573947  6.104977  54.736479
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon   DEM   Slope  \
# 5385  ...    6.756703     0.01058    0.184674  37.5372  127.085  28.7  0.6233
#
#       Solar radiation  Next_Tmax  Next_Tmin
# 5385       5448.95752       32.7       26.0
#
# [1 rows x 25 columns]

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS-EDA

# %%
# This dataset contains 7752 rows and 25 columns.
df.shape
# Out:
# (7752, 25)

# %%
# These are the columns are present in the dataset.
df.columns.tolist()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
df.dtypes   # Date is in object datatype.
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
# Null values are present in the dataset.
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
# Visualizing null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info() # The dataset has null values and date is in object datatype, rows are indexed from 0 to 7751 and memory usage is 1.5+MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1.0     310
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 13.0    310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: station, dtype: int64
#
#
# 30-06-2013    25
# 18-07-2016    25
# 25-07-2016    25
# 24-07-2016    25
# 23-07-2016    25
#               ..
# 09-08-2014    25
# 08-08-2014    25
# 07-08-2014    25
# 06-08-2014    25
# 30-08-2017    25
# Name: Date, Length: 310, dtype: int64
#
#
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# Name: Present_Tmax, Length: 167, dtype: int64
#
#
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 13.6      1
# 14.2      1
# 29.1      1
# 29.7      1
# 15.0      1
# ...

# %% [markdown]
# No wide values are present in the dataset. There are 23 independent features and 2 target variable or Label.

# %%
df['Date'].value_counts()
# Out:
# 30-06-2013    25
# 18-07-2016    25
# 25-07-2016    25
# 24-07-2016    25
# 23-07-2016    25
#               ..
# 09-08-2014    25
# 08-08-2014    25
# 07-08-2014    25
# 06-08-2014    25
# 30-08-2017    25
# Name: Date, Length: 310, dtype: int64

# %%
df['Date'].unique()
# Out:
# array(['30-06-2013', '01-07-2013', '02-07-2013', '03-07-2013',
#        '04-07-2013', '05-07-2013', '06-07-2013', '07-07-2013',
#        '08-07-2013', '09-07-2013', '10-07-2013', '11-07-2013',
#        '12-07-2013', '13-07-2013', '14-07-2013', '15-07-2013',
#        '16-07-2013', '17-07-2013', '18-07-2013', '19-07-2013',
#        '20-07-2013', '21-07-2013', '22-07-2013', '23-07-2013',
#        '24-07-2013', '25-07-2013', '26-07-2013', '27-07-2013',
#        '28-07-2013', '29-07-2013', '30-07-2013', '31-07-2013',
#        '01-08-2013', '02-08-2013', '03-08-2013', '04-08-2013',
#        '05-08-2013', '06-08-2013', '07-08-2013', '08-08-2013',
#        '09-08-2013', '10-08-2013', '11-08-2013', '12-08-2013',
#        '13-08-2013', '14-08-2013', '15-08-2013', '16-08-2013',
#        '17-08-2013', '18-08-2013', '19-08-2013', '20-08-2013',
#        '21-08-2013', '22-08-2013', '23-08-2013', '24-08-2013',
#        '25-08-2013', '26-08-2013', '27-08-2013', '28-08-2013',
# ...

# %%
df['Date'].nunique()
# Out:
# 310

# %%
# Treating NAN values 
df.dropna(inplace=True)

# %% [markdown]
# Since we have large dataset so dropping the nan values from the dataset. 162 nan values are removed from the dataset.

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.shape
# Out:
# (7588, 25)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate rows are present in the dataset.

# %%
# Date is in object datatype so changing to datetime.
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# dtype: object

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7588.000000   7588.000000   7588.000000  7588.000000  7588.000000
# mean     13.014101     29.748366     23.195809    56.724969    88.360823
# std       7.217858      2.967401      2.400880    14.626559     7.199456
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960243    84.203724
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.115099    93.742725
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7588.000000       7588.000000  7588.000000  7588.000000
# mean          29.620128         23.511786     7.094097    62.492606
# std            2.943496          2.342579     2.177034    33.686158
# ...

# %% [markdown]
# * Count of all the column is equal.
# * 'DEM' column mean is greater than median so the data is Right skewed.
# * 'Solar radiation' median is greater than mean its a left skewed data. In other columns difference is there but not much skewness.
# * Very less outliers are present in the dataset.

# %%
# We don't need a Date column to predict the next day min & max temperature so droping the column.
df.drop('Date',inplace=True,axis=1)

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936  6.818887   69.451805   0.233947
# ...

# %%
# Univariant analysis
sns.violinplot(df['station'])
# Out:
# <AxesSubplot:xlabel='station'>

# %%
sns.countplot(df['station'])
# Out:
# <AxesSubplot:xlabel='station', ylabel='count'>

# %%
sns.violinplot(df['Present_Tmax'])
# Out:
# <AxesSubplot:xlabel='Present_Tmax'>

# %%
sns.distplot(df['Present_Tmin'])
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Density'>

# %%
sns.violinplot(df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='Next_Tmax'>

# %%
sns.boxplot(df['LDAPS_RHmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin'>

# %%
sns.distplot(df['lat'])
# Out:
# <AxesSubplot:xlabel='lat', ylabel='Density'>

# %%
sns.distplot(df['lon'])
# Out:
# <AxesSubplot:xlabel='lon', ylabel='Density'>

# %%
sns.histplot(df['LDAPS_RHmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Count'>

# %%
# Bivariant analysis
sns.lineplot(x='Present_Tmax',y='Present_Tmin',data=df)
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Present_Tmin'>

# %%
sns.lmplot(x='Present_Tmax',y='Next_Tmax',data=df)

# %%
sns.scatterplot(x='Next_Tmax',y='Next_Tmin',data=df)
# Out:
# <AxesSubplot:xlabel='Next_Tmax', ylabel='Next_Tmin'>

# %%
sns.relplot(x='LDAPS_RHmin',y='LDAPS_Tmin_lapse',data=df)

# %%
sns.lineplot(x='LDAPS_WS',y='LDAPS_LH',data=df)
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_LH'>

# %%
sns.lmplot(x='LDAPS_CC1',y='LDAPS_CC2',data=df)

# %%
sns.scatterplot(x='LDAPS_CC3',y='LDAPS_CC4',data=df)
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_CC4'>

# %%
sns.lmplot(x='LDAPS_PPT1',y='LDAPS_PPT2',data=df)

# %%
sns.lineplot(x='LDAPS_PPT3',y='LDAPS_PPT1',data=df)
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_PPT1'>

# %%
sns.scatterplot(x='lat',y='lon',data=df)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='lon'>

# %%
sns.lineplot(x='DEM',y='Slope',data=df)
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Slope'>

# %%
sns.lmplot(x='Slope',y='Solar radiation',data=df)

# %%
# Checking how the data is distributed in each column.
plt.figure(figsize=(20,20))
plot_no=1
for i in df.columns:
    if plot_no<=25:
        plt.subplot(9,3,plot_no)
        sns.distplot(df[i])
        plt.xlabel(i)
    plot_no+=1
plt.show()

# %%
# Checking outliers are present in each column.
plt.figure(figsize=(20,20))
plot_no=1
for i in df.columns:
    if plot_no<=25:
        plt.subplot(9,3,plot_no)
        sns.boxplot(df[i])
        plt.xlabel(i)
    plot_no+=1
plt.show()

# %%
# Checking correlation between features and target variable.

plt.figure(figsize=(20,20))
plot_no=1
for i in df.columns:
    if plot_no<=25:
        plt.subplot(9,3,plot_no)
        sns.lineplot(x='Next_Tmin',y=i,data=df)
        plt.xlabel("Next Day Minimum Temp")
        plt.ylabel(i)
    plot_no+=1
plt.tight_layout()

# %%
# Checking correlation between features and target variable.

plt.figure(figsize=(20,20))
plot_no=1
for i in df.columns:
    if plot_no<=25:
        plt.subplot(9,3,plot_no)
        sns.lineplot(x='Next_Tmax',y=i,data=df)
        plt.xlabel("Next Day Maximum Temp")
        plt.ylabel(i)
    plot_no+=1
plt.tight_layout()

# %% [markdown]
# ## Applying Feature Engineering

# %%
# Importing zscore to remove the outliers.
from scipy.stats import zscore
features=df.drop(['Next_Tmin','Next_Tmax'],axis=1)
features
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936  6.818887   69.451805   0.233947
# ...

# %%
z=np.abs(zscore(features))
z
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0     1.664607      0.353318      0.748029     0.104660     0.382768
# 1     1.526052      0.725138      0.664721     0.305052     0.311697
# 2     1.387498      0.624033      0.043400     0.549344     0.609425
# 3     1.248943      0.758840      0.085054     0.103573     1.128335
# 4     1.110389      0.556630      0.539758     0.037665     0.249244
# ...        ...           ...           ...          ...          ...
# 7745  1.106481      2.240616      2.247578     2.190405     1.402898
# 7746  1.245036      2.442826      2.414195     1.820788     0.648815
# 7747  1.383590      2.173212      2.539157     2.050081     1.318376
# 7748  1.522145      2.173212      2.289232     2.234735     1.537141
# 7749  1.660699      2.206914      2.414195     2.310467     1.544257
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7581, 7582, 7582], dtype=int64),
#  array([ 7, 14, 14, ...,  2,  2,  6], dtype=int64))

# %%
z.iloc[25,7]
# Out:
# 3.911059950709196

# %%
z.iloc[25,14]
# Out:
# 5.422387453409173

# %%
# Removing the outliers 
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (6752, 24)

# %%
print("Data loss percntage is ",(df.shape[0]-df1.shape[0])/df.shape[0]*100)
# Out:
# Data loss percntage is  11.017395888244597

# %% [markdown]
# Data loss is in acceptable range.

# %%
# Checking skewness.
df1.skew()
# Out:
# station            -0.002155
# Present_Tmax       -0.272176
# Present_Tmin       -0.228280
# LDAPS_RHmin         0.310510
# LDAPS_RHmax        -0.683451
# LDAPS_Tmax_lapse   -0.108972
# LDAPS_Tmin_lapse   -0.393491
# LDAPS_WS            1.083709
# LDAPS_LH            0.563986
# LDAPS_CC1           0.594870
# LDAPS_CC2           0.506390
# LDAPS_CC3           0.703080
# LDAPS_CC4           0.709748
# LDAPS_PPT1          3.728629
# LDAPS_PPT2          4.860127
# LDAPS_PPT3          5.518685
# LDAPS_PPT4          5.929500
# lat                 0.104976
# lon                -0.278235
# DEM                 1.762057
# Slope               1.588860
# Solar radiation    -0.518382
# Next_Tmax          -0.267742
# Next_Tmin          -0.290919
# dtype: float64

# %%
df1['LDAPS_PPT4']=np.cbrt(df1['LDAPS_PPT4'])

# %%
df1.skew()
# Out:
# station            -0.002155
# Present_Tmax       -0.272176
# Present_Tmin       -0.228280
# LDAPS_RHmin         0.310510
# LDAPS_RHmax        -0.683451
# LDAPS_Tmax_lapse   -0.108972
# LDAPS_Tmin_lapse   -0.393491
# LDAPS_WS            1.083709
# LDAPS_LH            0.563986
# LDAPS_CC1           0.594870
# LDAPS_CC2           0.506390
# LDAPS_CC3           0.703080
# LDAPS_CC4           0.709748
# LDAPS_PPT1          3.728629
# LDAPS_PPT2          4.860127
# LDAPS_PPT3          5.518685
# LDAPS_PPT4          2.849526
# lat                 0.104976
# lon                -0.278235
# DEM                 1.762057
# Slope               1.588860
# Solar radiation    -0.518382
# Next_Tmax          -0.267742
# Next_Tmin          -0.290919
# dtype: float64

# %%
df1['LDAPS_PPT3']=np.cbrt(df1['LDAPS_PPT3'])

# %%
df1.skew()
# Out:
# station            -0.002155
# Present_Tmax       -0.272176
# Present_Tmin       -0.228280
# LDAPS_RHmin         0.310510
# LDAPS_RHmax        -0.683451
# LDAPS_Tmax_lapse   -0.108972
# LDAPS_Tmin_lapse   -0.393491
# LDAPS_WS            1.083709
# LDAPS_LH            0.563986
# LDAPS_CC1           0.594870
# LDAPS_CC2           0.506390
# LDAPS_CC3           0.703080
# LDAPS_CC4           0.709748
# LDAPS_PPT1          3.728629
# LDAPS_PPT2          4.860127
# LDAPS_PPT3          2.505909
# LDAPS_PPT4          2.849526
# lat                 0.104976
# lon                -0.278235
# DEM                 1.762057
# Slope               1.588860
# Solar radiation    -0.518382
# Next_Tmax          -0.267742
# Next_Tmin          -0.290919
# dtype: float64

# %%
df1['LDAPS_PPT2']=np.cbrt(df1['LDAPS_PPT2'])

# %%
df1.skew()
# Out:
# station            -0.002155
# Present_Tmax       -0.272176
# Present_Tmin       -0.228280
# LDAPS_RHmin         0.310510
# LDAPS_RHmax        -0.683451
# LDAPS_Tmax_lapse   -0.108972
# LDAPS_Tmin_lapse   -0.393491
# LDAPS_WS            1.083709
# LDAPS_LH            0.563986
# LDAPS_CC1           0.594870
# LDAPS_CC2           0.506390
# LDAPS_CC3           0.703080
# LDAPS_CC4           0.709748
# LDAPS_PPT1          3.728629
# LDAPS_PPT2          2.345147
# LDAPS_PPT3          2.505909
# LDAPS_PPT4          2.849526
# lat                 0.104976
# lon                -0.278235
# DEM                 1.762057
# Slope               1.588860
# Solar radiation    -0.518382
# Next_Tmax          -0.267742
# Next_Tmin          -0.290919
# dtype: float64

# %%
df1['LDAPS_PPT1']=np.cbrt(df1['LDAPS_PPT1'])

# %%
df1.skew()
# Out:
# station            -0.002155
# Present_Tmax       -0.272176
# Present_Tmin       -0.228280
# LDAPS_RHmin         0.310510
# LDAPS_RHmax        -0.683451
# LDAPS_Tmax_lapse   -0.108972
# LDAPS_Tmin_lapse   -0.393491
# LDAPS_WS            1.083709
# LDAPS_LH            0.563986
# LDAPS_CC1           0.594870
# LDAPS_CC2           0.506390
# LDAPS_CC3           0.703080
# LDAPS_CC4           0.709748
# LDAPS_PPT1          1.924504
# LDAPS_PPT2          2.345147
# LDAPS_PPT3          2.505909
# LDAPS_PPT4          2.849526
# lat                 0.104976
# lon                -0.278235
# DEM                 1.762057
# Slope               1.588860
# Solar radiation    -0.518382
# Next_Tmax          -0.267742
# Next_Tmin          -0.290919
# dtype: float64

# %% [markdown]
# Almost skewness is reduced so lets proceed with same skewness values.

# %%
df1.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.111032      0.134279    -0.069313
# Present_Tmax      0.111032      1.000000      0.611980    -0.151525
# Present_Tmin      0.134279      0.611980      1.000000     0.154390
# LDAPS_RHmin      -0.069313     -0.151525      0.154390     1.000000
# LDAPS_RHmax      -0.175128     -0.293747     -0.035518     0.553390
# LDAPS_Tmax_lapse  0.067499      0.541375      0.443528    -0.552364
# LDAPS_Tmin_lapse  0.104742      0.617808      0.766265     0.133667
# LDAPS_WS          0.021791     -0.107307      0.016017     0.235370
# LDAPS_LH         -0.134588      0.128330     -0.007702    -0.037061
# LDAPS_CC1         0.008513     -0.287750      0.092447     0.575085
# LDAPS_CC2         0.006717     -0.154672      0.120908     0.713774
# LDAPS_CC3         0.006932     -0.059344      0.043030     0.654057
# LDAPS_CC4         0.010531     -0.048757     -0.005601     0.458798
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df1.corr(),annot=True,cmap='cividis')
plt.show()

# %%
# Separating x and y as features and target variable.
x=df1.drop('Next_Tmin',axis=1)
y=df1['Next_Tmin']

# %%
x.shape
# Out:
# (6752, 23)

# %%
y.shape
# Out:
# (6752,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.672742     -0.422834     -0.807713     0.197880     0.439052
# 1    -1.533950      0.691425     -0.721339    -0.234410     0.365795
# 2    -1.395157      0.586963      0.012837    -0.492163    -0.583657
# 3    -1.256365      0.726245      0.056024     0.196732     1.207551
# 4    -1.117573      0.517322     -0.591779     0.047712     0.301422
# ...        ...           ...           ...          ...          ...
# 6747  1.103102     -2.372786     -2.362440    -2.223652    -1.401536
# 6748  1.241894     -2.581710     -2.535187    -1.833669    -0.624259
# 6749  1.380686     -2.303145     -2.664748    -2.075597    -1.314414
# 6750  1.519478     -2.303145     -2.405627    -2.270426    -1.539907
# 6751  1.658271     -2.337966     -2.535187    -2.350331    -1.547242
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Features']=x.columns
vif['Vif Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#             Features  Vif Values
# 0            station    1.239213
# 1       Present_Tmax    2.872936
# 2       Present_Tmin    3.111147
# 3        LDAPS_RHmin    5.948134
# 4        LDAPS_RHmax    2.253152
# 5   LDAPS_Tmax_lapse    8.188908
# 6   LDAPS_Tmin_lapse    7.086527
# 7           LDAPS_WS    1.252857
# 8           LDAPS_LH    1.571092
# 9          LDAPS_CC1    4.893103
# 10         LDAPS_CC2    5.380967
# 11         LDAPS_CC3    5.133454
# 12         LDAPS_CC4    3.100106
# 13        LDAPS_PPT1    2.675699
# 14        LDAPS_PPT2    2.165860
# 15        LDAPS_PPT3    1.686520
# 16        LDAPS_PPT4    1.734801
# 17               lat    1.228240
# 18               lon    1.181875
# 19               DEM    3.151852
# 20             Slope    2.974202
# 21   Solar radiation    1.248579
# 22         Next_Tmax    4.218934

# %% [markdown]
# Multicolinearity is present in the dataset but VIF Values are in acceptable range so lets proceed with same vif values.

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor,GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# Finding the best accuracy in random state.
maxacc=0
maxrs=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predict_lr=lr.predict(x_test)
    acc=r2_score(y_test,predict_lr)
    if acc>=maxacc:
        maxacc=acc
        maxrs=i
print("Best r2 score is ",maxacc,"in random state",maxrs)
# Out:
# Best r2 score is  0.8617378036505726 in random state 253

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=maxrs,test_size=0.20)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predict_LR=LR.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_LR))
print("Mean absolute error ",mean_absolute_error(y_test,predict_LR))
print("Mean squared error ",mean_squared_error(y_test,predict_LR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,predict_LR)))
print("\n")
cvs=cross_val_score(LR,x,y,cv=5).mean()
print("Cross Validation score is ",cvs)
print("Difference between r2 score and cross val score ",r2_score(y_test,predict_LR)-cvs )
# Out:
# R2 Score  0.8617378036505726
# Mean absolute error  0.7181738262908933
# Mean squared error  0.8093932640623485
# Root mean squared error  0.8996628613332599
#
#
# Cross Validation score is  0.7941344602303697
# Difference between r2 score and cross val score  0.06760334342020291

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predict_RFR=RFR.predict(x_test)
print("R2 Score ",r2_score(y_test,predict_RFR))
print("Mean absolute error ",mean_absolute_error(y_test,predict_RFR))
print("Mean squared error ",mean_squared_error(y_test,predict_RFR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,predict_RFR)))
print("\n")
cvs=cross_val_score(RFR,x,y,cv=5).mean()
print("Cross Validation score is ",cvs)
print("The difference between r2 score and cross val score ",r2_score(y_test,predict_RFR)-cvs)
# Out:
# R2 Score  0.9136429621265074
# Mean absolute error  0.5448978534418948
# Mean squared error  0.505538076239822
# Root mean squared error  0.7110120085060604
#
#
# Cross Validation score is  0.7945078477033068
# The difference between r2 score and cross val score  0.11913511442320057

# %%
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_ETR=ETR.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_ETR))
print("Mean absolute error ",mean_absolute_error(y_test,pred_ETR))
print("Mean squared error ",mean_squared_error(y_test,pred_ETR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_ETR)))
print("\n")
cvs=cross_val_score(ETR,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_ETR)-cvs)
# Out:
# R2 Score  0.9215596547560735
# Mean absolute error  0.5134922279792745
# Mean squared error  0.45919339304219087
# Root mean squared error  0.6776380988715074
#
#
# Cross Val score :  0.7980286308852423
# The Difference between R2 score and cross val score  0.12353102387083115

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_GBR))
print("Mean absolute error ",mean_absolute_error(y_test,pred_GBR))
print("Mean squared error ",mean_squared_error(y_test,pred_GBR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_GBR)))
print("\n")
cvs=cross_val_score(GBR,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_GBR)-cvs)
# Out:
# R2 Score  0.9081844507422497
# Mean absolute error  0.5758913772594539
# Mean squared error  0.5374924532342397
# Root mean squared error  0.733138768061163
#
#
# Cross Val score :  0.8053743015801753
# The Difference between R2 score and cross val score  0.10281014916207443

# %%
ABR=AdaBoostRegressor()
ABR.fit(x_train,y_train)
pred_ABR=ABR.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_ABR))
print("Mean absolute error ",mean_absolute_error(y_test,pred_ABR))
print("Mean squared error ",mean_squared_error(y_test,pred_ABR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_ABR)))
print("\n")
cvs=cross_val_score(ABR,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_ABR)-cvs)
# Out:
# R2 Score  0.8158290248816535
# Mean absolute error  0.8501093058578836
# Mean squared error  1.0781453689615241
# Root mean squared error  1.03833779135767
#
#
# Cross Val score :  0.7460658479965931
# The Difference between R2 score and cross val score  0.0697631768850604

# %%
BR=BaggingRegressor()
BR.fit(x_train,y_train)
pred_BR=BR.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_BR))
print("Mean absolute error ",mean_absolute_error(y_test,pred_BR))
print("Mean squared error ",mean_squared_error(y_test,pred_BR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_BR)))
print("\n")
cvs=cross_val_score(BR,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_BR)-cvs)
# Out:
# R2 Score  0.9018788173383362
# Mean absolute error  0.5737971872686899
# Mean squared error  0.5744059215396001
# Root mean squared error  0.7578957194361241
#
#
# Cross Val score :  0.7787126403382711
# The Difference between R2 score and cross val score  0.12316617700006505

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_DTR))
print("Mean absolute error ",mean_absolute_error(y_test,pred_DTR))
print("Mean squared error ",mean_squared_error(y_test,pred_DTR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_DTR)))
print("\n")
cvs=cross_val_score(DTR,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_DTR)-cvs)
# Out:
# R2 Score  0.7980734464486114
# Mean absolute error  0.8168763878608437
# Mean squared error  1.1820873427091043
# Root mean squared error  1.0872384019657806
#
#
# Cross Val score :  0.5957663125241637
# The Difference between R2 score and cross val score  0.20230713392444777

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
pred_knr=knr.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_knr))
print("Mean absolute error ",mean_absolute_error(y_test,pred_knr))
print("Mean squared error ",mean_squared_error(y_test,pred_knr))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_knr)))
print("\n")
cvs=cross_val_score(knr,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_knr)-cvs)
# Out:
# R2 Score  0.8784292902447023
# Mean absolute error  0.642383419689119
# Mean squared error  0.7116805329385639
# Root mean squared error  0.843611600761016
#
#
# Cross Val score :  0.6433231785156572
# The Difference between R2 score and cross val score  0.23510611172904505

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
pred_rdg=rdg.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_rdg))
print("Mean absolute error ",mean_absolute_error(y_test,pred_rdg))
print("Mean squared error ",mean_squared_error(y_test,pred_rdg))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_rdg)))
print("\n")
cvs=cross_val_score(rdg,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_rdg)-cvs)
# Out:
# R2 Score  0.86173328820458
# Mean absolute error  0.718193323274931
# Mean squared error  0.8094196976911149
# Root mean squared error  0.8996775520658026
#
#
# Cross Val score :  0.7941553493426599
# The Difference between R2 score and cross val score  0.0675779388619201

# %%
lso=Lasso()
lso.fit(x_train,y_train)
pred_lso=lso.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_lso))
print("Mean absolute error ",mean_absolute_error(y_test,pred_lso))
print("Mean squared error ",mean_squared_error(y_test,pred_lso))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_lso)))
print("\n")
cvs=cross_val_score(lso,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_lso)-cvs)
# Out:
# R2 Score  0.6031456094606953
# Mean absolute error  1.2208771573203119
# Mean squared error  2.3232038763820215
# Root mean squared error  1.5242059822681517
#
#
# Cross Val score :  0.5414572353200372
# The Difference between R2 score and cross val score  0.06168837414065809

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print("R2 Score ",r2_score(y_test,pred_svr))
print("Mean absolute error ",mean_absolute_error(y_test,pred_svr))
print("Mean squared error ",mean_squared_error(y_test,pred_svr))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,pred_svr)))
print("\n")
cvs=cross_val_score(svr,x,y).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y_test,pred_svr)-cvs)
# Out:
# R2 Score  0.9227334070575277
# Mean absolute error  0.5153389334055218
# Mean squared error  0.4523221930210823
# Root mean squared error  0.6725490264814026
#
#
# Cross Val score :  0.7684704720625393
# The Difference between R2 score and cross val score  0.15426293499498844

# %% [markdown]
# Out of all models Extra Trees Regressor and Support Vector Regressor is working wel and cross validation score also in acceptable range so lets consider Extra Trees Regressor is our final model and will improve the model performance by using Hyper parameter tuning.

# %%
# Using GridSearchCV tuning model performance.

from sklearn.model_selection import GridSearchCV
parameters={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']}
gscv=GridSearchCV(ExtraTreesRegressor(),parameters,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson']})

# %%
gscv.best_params_
# Out:
# {'criterion': 'friedman_mse'}

# %%
final_model=ExtraTreesRegressor(criterion='friedman_mse')
final_model.fit(x_train,y_train)
predict_finmodel=final_model.predict(x_test)
r2score=r2_score(y_test,predict_finmodel)
print(r2score*100)
# Out:
# 92.36240873545846

# %%
import joblib
joblib.dump(final_model,'Temp forecasting min.pkl')
# Out:
# ['Temp forecasting min.pkl']

# %%
model=joblib.load('Temp forecasting min.pkl')
prediction=model.predict(x_test)
prediction
# Out:
# array([24.885, 26.926, 23.336, ..., 22.482, 26.722, 21.292])

# %%
data1=pd.DataFrame({'Y Test':y_test,'Pred':prediction},columns=['Y Test','Pred'])
sns.lineplot(x='Y Test',y='Pred',data=data1)
data1
# Out:
#       Y Test    Pred
# 5601    24.8  24.885
# 1155    27.0  26.926
# 7216    22.6  23.336
# 1820    23.0  23.428
# 4790    18.7  20.105
# ...      ...     ...
# 2651    19.8  19.795
# 1668    21.7  21.770
# 7511    22.1  22.482
# 5589    27.0  26.722
# 5134    21.6  21.292
#
# [1351 rows x 2 columns]

# %% [markdown]
# ## Predicting Maximum Temperature

# %%
x1=df1.drop('Next_Tmax',axis=1)
y1=df1['Next_Tmax']

# %%
x1.shape
# Out:
# (6752, 23)

# %%
y1.shape
# Out:
# (6752,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x1=pd.DataFrame(scaler.fit_transform(x1.values),columns=x1.columns)
x1
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.672742     -0.422834     -0.807713     0.197880     0.439052
# 1    -1.533950      0.691425     -0.721339    -0.234410     0.365795
# 2    -1.395157      0.586963      0.012837    -0.492163    -0.583657
# 3    -1.256365      0.726245      0.056024     0.196732     1.207551
# 4    -1.117573      0.517322     -0.591779     0.047712     0.301422
# ...        ...           ...           ...          ...          ...
# 6747  1.103102     -2.372786     -2.362440    -2.223652    -1.401536
# 6748  1.241894     -2.581710     -2.535187    -1.833669    -0.624259
# 6749  1.380686     -2.303145     -2.664748    -2.075597    -1.314414
# 6750  1.519478     -2.303145     -2.405627    -2.270426    -1.539907
# 6751  1.658271     -2.337966     -2.535187    -2.350331    -1.547242
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Features']=x1.columns
vif['VIF Values']=[variance_inflation_factor(x1.values,i) for i in range(len(x1.columns))]
vif
# Out:
#             Features  VIF Values
# 0            station    1.231784
# 1       Present_Tmax    2.790346
# 2       Present_Tmin    3.352101
# 3        LDAPS_RHmin    5.982059
# 4        LDAPS_RHmax    2.251347
# 5   LDAPS_Tmax_lapse    6.902302
# 6   LDAPS_Tmin_lapse    9.010323
# 7           LDAPS_WS    1.234136
# 8           LDAPS_LH    1.535575
# 9          LDAPS_CC1    4.883880
# 10         LDAPS_CC2    5.394247
# 11         LDAPS_CC3    5.120922
# 12         LDAPS_CC4    3.022108
# 13        LDAPS_PPT1    2.669486
# 14        LDAPS_PPT2    2.187148
# 15        LDAPS_PPT3    1.686040
# 16        LDAPS_PPT4    1.739154
# 17               lat    1.228997
# 18               lon    1.174910
# 19               DEM    3.320473
# 20             Slope    3.050272
# 21   Solar radiation    1.246660
# 22         Next_Tmin    5.701126

# %% [markdown]
# Mulitcolinearity is present but its in acceptable range so lets proceed with same VIF value to train the model.

# %%
# Finding the best randomstate for better r2 score
maxacc=0
maxrs=0
for i in range(1,1000):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,random_state=i,test_size=0.20)
    lr1=LinearRegression()
    lr1.fit(x1_train,y1_train)
    predictlr1=lr1.predict(x1_test)
    acc=r2_score(y1_test,predictlr1)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print("Best r2 score ",maxacc,'at the random state ',maxrs)
# Out:
# Best r2 score  0.8122797494398434 at the random state  460

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,random_state=maxrs,test_size=0.20)

# %%
LR1=LinearRegression()
LR1.fit(x1_train,y1_train)
predict_LR1=LR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,predict_LR1))
print("Mean absolute error ",mean_absolute_error(y1_test,predict_LR1))
print("Mean squared error ",mean_squared_error(y1_test,predict_LR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,predict_LR1)))
print("\n")
cvs=cross_val_score(LR1,x1,y1,cv=5).mean()
print("Cross Validation score is ",cvs)
print("Difference between r2 score and cross val score ",r2_score(y1_test,predict_LR1)-cvs )
# Out:
# R2 Score  0.8122797494398434
# Mean absolute error  0.9912183507451664
# Mean squared error  1.6537567927136436
# Root mean squared error  1.2859847560191542
#
#
# Cross Validation score is  0.7183378434803244
# Difference between r2 score and cross val score  0.09394190595951901

# %%
RFR1=RandomForestRegressor()
RFR1.fit(x1_train,y1_train)
predict_RFR1=RFR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,predict_RFR1))
print("Mean absolute error ",mean_absolute_error(y1_test,predict_RFR1))
print("Mean squared error ",mean_squared_error(y1_test,predict_RFR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,predict_RFR1)))
print("\n")
cvs=cross_val_score(RFR1,x1,y1,cv=5).mean()
print("Cross Validation score is ",cvs)
print("The difference between r2 score and cross val score ",r2_score(y1_test,predict_RFR1)-cvs)
# Out:
# R2 Score  0.9024377470456407
# Mean absolute error  0.6997742413027385
# Mean squared error  0.8594929851961505
# Root mean squared error  0.9270884451853288
#
#
# Cross Validation score is  0.691607783230707
# The difference between r2 score and cross val score  0.21082996381493369

# %%
ETR1=ExtraTreesRegressor()
ETR1.fit(x1_train,y1_train)
pred_ETR1=ETR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_ETR1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_ETR1))
print("Mean squared error ",mean_squared_error(y1_test,pred_ETR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_ETR1)))
print("\n")
cvs=cross_val_score(ETR1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_ETR1)-cvs)
# Out:
# R2 Score  0.9223586563899393
# Mean absolute error  0.6289104367135454
# Mean squared error  0.6839959940784602
# Root mean squared error  0.8270405032877532
#
#
# Cross Val score :  0.7001023220383117
# The Difference between R2 score and cross val score  0.22225633435162762

# %%
GBR1=GradientBoostingRegressor()
GBR1.fit(x1_train,y1_train)
pred_GBR1=GBR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_GBR1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_GBR1))
print("Mean squared error ",mean_squared_error(y1_test,pred_GBR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_GBR1)))
print("\n")
cvs=cross_val_score(GBR1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_GBR1)-cvs)
# Out:
# R2 Score  0.858749486368255
# Mean absolute error  0.8519526666422002
# Mean squared error  1.2443729203202405
# Root mean squared error  1.1155146437049763
#
#
# Cross Val score :  0.6989405927931212
# The Difference between R2 score and cross val score  0.15980889357513384

# %%
ABR1=AdaBoostRegressor()
ABR1.fit(x1_train,y1_train)
pred_ABR1=ABR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_ABR1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_ABR1))
print("Mean squared error ",mean_squared_error(y1_test,pred_ABR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_ABR1)))
print("\n")
cvs=cross_val_score(ABR1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_ABR1)-cvs)
# Out:
# R2 Score  0.7702108455660523
# Mean absolute error  1.1431173084810178
# Mean squared error  2.0243707000342313
# Root mean squared error  1.4228038164252412
#
#
# Cross Val score :  0.6554656435949542
# The Difference between R2 score and cross val score  0.11474520197109817

# %%
DTR1=DecisionTreeRegressor()
DTR1.fit(x1_train,y1_train)
pred_DTR1=DTR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_DTR1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_DTR1))
print("Mean squared error ",mean_squared_error(y1_test,pred_DTR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_DTR1)))
print("\n")
cvs=cross_val_score(DTR1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_DTR1)-cvs)
# Out:
# R2 Score  0.7785334591245276
# Mean absolute error  1.017542561065877
# Mean squared error  1.9510510732790525
# Root mean squared error  1.3968002982814158
#
#
# Cross Val score :  0.4484600907262122
# The Difference between R2 score and cross val score  0.33007336839831547

# %%
knr1=KNeighborsRegressor()
knr1.fit(x1_train,y1_train)
pred_knr1=knr1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_knr1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_knr1))
print("Mean squared error ",mean_squared_error(y1_test,pred_knr1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_knr1)))
print("\n")
cvs=cross_val_score(knr1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_knr1)-cvs)
# Out:
# R2 Score  0.8728728769711905
# Mean absolute error  0.7983419689119171
# Mean squared error  1.1199502590673578
# Root mean squared error  1.058277023783167
#
#
# Cross Val score :  0.5676537917862422
# The Difference between R2 score and cross val score  0.30521908518494834

# %%
rdg1=Ridge()
rdg1.fit(x1_train,y1_train)
pred_rdg1=rdg1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_rdg1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_rdg1))
print("Mean squared error ",mean_squared_error(y1_test,pred_rdg1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_rdg1)))
print("\n")
cvs=cross_val_score(rdg1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_rdg1)-cvs)
# Out:
# R2 Score  0.8122727561297158
# Mean absolute error  0.9912429271090328
# Mean squared error  1.6538184015922406
# Root mean squared error  1.2860087097653112
#
#
# Cross Val score :  0.7183738246469238
# The Difference between R2 score and cross val score  0.09389893148279205

# %%
lso1=Lasso()
lso1.fit(x1_train,y1_train)
pred_lso1=lso1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_lso1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_lso1))
print("Mean squared error ",mean_squared_error(y1_test,pred_lso1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_lso1)))
print("\n")
cvs=cross_val_score(lso1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_lso1)-cvs)
# Out:
# R2 Score  0.5660082032837723
# Mean absolute error  1.5603532202401007
# Mean squared error  3.8233322172743516
# Root mean squared error  1.9553342980867368
#
#
# Cross Val score :  0.498171342717184
# The Difference between R2 score and cross val score  0.06783686056658833

# %%
svr1=SVR()
svr1.fit(x1_train,y1_train)
pred_svr1=svr1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_svr1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_svr1))
print("Mean squared error ",mean_squared_error(y1_test,pred_svr1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_svr1)))
print("\n")
cvs=cross_val_score(svr1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_svr1)-cvs)
# Out:
# R2 Score  0.8896824809462431
# Mean absolute error  0.7266514644301512
# Mean squared error  0.9718628967629859
# Root mean squared error  0.985831069079782
#
#
# Cross Val score :  0.6891429717069588
# The Difference between R2 score and cross val score  0.20053950923928432

# %%
BR1=BaggingRegressor()
BR1.fit(x1_train,y1_train)
pred_BR1=BR1.predict(x1_test)
print("R2 Score ",r2_score(y1_test,pred_BR1))
print("Mean absolute error ",mean_absolute_error(y1_test,pred_BR1))
print("Mean squared error ",mean_squared_error(y1_test,pred_BR1))
print("Root mean squared error ",np.sqrt(mean_squared_error(y1_test,pred_BR1)))
print("\n")
cvs=cross_val_score(BR1,x1,y1).mean()
print("Cross Val score : ",cvs)
print("The Difference between R2 score and cross val score ",r2_score(y1_test,pred_BR1)-cvs)
# Out:
# R2 Score  0.8905139770413429
# Mean absolute error  0.7437305699481865
# Mean squared error  0.9645376757957066
# Root mean squared error  0.9821087902038687
#
#
# Cross Val score :  0.6738722865922746
# The Difference between R2 score and cross val score  0.21664169044906834

# %% [markdown]
# Out of all models Extra trees are working wel.

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']}

gscv1=GridSearchCV(ExtraTreesRegressor(),parameters,cv=5)
gscv1.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson']})

# %%
gscv.best_params_
# Out:
# {'criterion': 'friedman_mse'}

# %%
final_model1=ExtraTreesRegressor(criterion='friedman_mse')
final_model1.fit(x1_train,y1_train)
predict_final_model=final_model1.predict(x1_test)
r2score=r2_score(y1_test,predict_final_model)
print(r2score*100)
# Out:
# 92.12976815401078

# %%
import joblib
joblib.dump(final_model1,"Temp forecasting model2.pkl")
# Out:
# ['Temp forecasting model2.pkl']

# %%
model1=joblib.load("Temp forecasting model2.pkl")
prediction1=model1.predict(x1_test)
prediction1
# Out:
# array([31.689, 32.192, 30.673, ..., 27.683, 29.39 , 34.218])

# %%
data2=pd.DataFrame()
data2['Original']=np.array(y1_test)
data2['Predicted']=prediction1
data2
# Out:
#       Original  Predicted
# 0         31.6     31.689
# 1         32.5     32.192
# 2         31.0     30.673
# 3         33.8     33.612
# 4         31.6     31.265
# ...        ...        ...
# 1346      31.8     32.133
# 1347      31.9     30.736
# 1348      27.1     27.683
# 1349      29.3     29.390
# 1350      33.9     34.218
#
# [1351 rows x 2 columns]

# %%
sns.scatterplot(x=y1_test,y=prediction1,data=data2)
# Out:
# <AxesSubplot:xlabel='Next_Tmax'>

# %% [markdown]
# Predicted Next day's Minimum and maximum temperature by using Regression. Compare to other models  Extra Trees Regressor is giving high accuracy for both target variable and improved model performance by using hyper parameter tuning and saved the final model and reloaded back and tested the model again.

# %% [markdown]
# # Thank You...
