# %%
import numpy as np                        # Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head()      # Displays first 5 rows from the dataset.
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.tail()       # Displays last five rows from the dataset.
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.sample()       # Randomly displays 1 row from the dataset.
# Out:
#        Age Workclass  Fnlwgt   Education  Education_num Marital_status  \
# 31030   53   Private  142411   Assoc-voc             11       Divorced
#
#             Occupation Relationship    Race      Sex  Capital_gain  \
# 31030   Prof-specialty    Unmarried   White   Female             0
#
#        Capital_loss  Hours_per_week  Native_country  Income
# 31030             0              40   United-States   <=50K

# %% [markdown]
# ## Exploratory Data Analysis-EDA

# %%
df.shape            # This dataset contains 32560 rows and 15 columns.
# Out:
# (32560, 15)

# %%
df.columns.to_list()      # These are the column name present in the dataset.
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
df.dtypes          # Two types of data are present in the dataset. int64,object.
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.info()           # The rows are indexed from 0 to 32559. memory usage 3.7+ MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()         # Checking null values.
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
sns.heatmap(df.isnull())         # Visualizing null values with heatmap
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:                  # Checking any wide values are present in the dataset.
    print(df[i].value_counts())
    print("\n")
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#
#
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#
#
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
#
#
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
# ...

# %% [markdown]
# In 'Workclass','Occupation','Native_country' these three columns we have '?' this values so need to replace.

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
# So lets treat with these '?' values to NAN values.
df=df.replace(" ?",np.nan)

# %%
df.isnull().sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
# Fill Nan values by using mode().
column_with_nan=['Workclass','Occupation','Native_country']
for i in column_with_nan:
    df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.duplicated().sum()       # 24 Duplicate rows are present in the dataset.
# Out:
# 24

# %%
df=df.drop_duplicates()     # Removing duplicates from the dataset.

# %%
df.duplicated().sum()       # Sucessfully removed from the dataset.
# Out:
# 0

# %%
df.describe()         # Shows statistical summary for numeric columns.
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32536.000000  3.253600e+04   32536.000000  32536.000000  32536.000000
# mean      38.585536  1.897843e+05      10.081725   1078.410069     87.370912
# std       13.638193  1.055563e+05       2.571622   7388.068465    403.107737
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369932e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32536.000000
# mean        40.440343
# std         12.347079
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# 1. Count of all columns are equal.
# 2. In 'Capital_gain','Capital_loss' mean is greater than median so the data is right skewed.
# 3. There is no left skewed data is present in the dataset.
# 4. 'Capital_gain','Capital_loss' outliers are present in these columns.

# %%
# Sepearting numeric column and categorical columns.
num_col=[]
cat_col=[]
for i in df.columns:
    if df[i].dtypes=='object':
        cat_col.append(i)
    else:
        num_col.append(i)
print("Numeric columns ",num_col)
print("\n")
print("Categorical columns ",cat_col)
# Out:
# Numeric columns  ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']
#
#
# Categorical columns  ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
# Univariant Analysis
sns.countplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.violinplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.histplot(df['Capital_gain'])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Count'>

# %%
sns.violinplot(df['Capital_loss'])
# Out:
# <AxesSubplot:xlabel='Capital_loss'>

# %%
sns.countplot(df['Relationship'])
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %%
# Bivariant Analysis
sns.stripplot(x='Workclass',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='Age'>

# %%
sns.catplot(x='Education',y='Capital_gain',data=df)

# %%
sns.scatterplot(x='Capital_gain',y='Capital_loss',data=df)
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Capital_loss'>

# %%
sns.lmplot(x='Age',y='Hours_per_week',data=df)

# %%
sns.relplot(x='Workclass',y='Hours_per_week',data=df)

# %%
sns.stripplot(x='Occupation',y='Hours_per_week',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Hours_per_week'>

# %%
sns.scatterplot(x='Fnlwgt',y='Hours_per_week',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Hours_per_week'>

# %%
# Multivariant Analysis
sns.pairplot(df)

# %%
# Visualizing skewness using distplot.
plt.figure(figsize=(20,10))
plt_no=1
for i in num_col:
    if plt_no<=6:
        ax=plt.subplot(3,2,plt_no)
        sns.distplot(df[i])
        plt.xlabel(i)
    plt_no+=1
plt.tight_layout()

# %%
# Visualizing any outliers are present.
plt.figure(figsize=(15,10),facecolor='Blue')
plt_no=1
for i in num_col:
    if plt_no<=6:
        ax=plt.subplot(3,2,plt_no)
        sns.boxplot(df[i])
        plt.xlabel(i)
    plt_no+=1
plt.tight_layout()

# %%
# Checking the correlation between independent variable with target variable.
plt.figure(figsize=(20,10))
plt_no=1
for i in df.columns:
    if plt_no<=15:
        ax=plt.subplot(5,3,plt_no)
        sns.scatterplot(x='Income',y=i,data=df)
        plt.xlabel("Income")
        plt.ylabel(i)
    plt_no+=1
plt.tight_layout()

# %%
# Encoding categorical column into numeric column for machine to understand better.
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=LE.fit_transform(df[i].values)
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
from scipy.stats import zscore
features=df.drop('Income',axis=1)
features
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
z=np.abs(zscore(features))
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.836961   1.720777  1.008703   0.335272       1.134817
# 1      0.042934   0.085203  0.245008   0.181506       0.420646
# 2      1.056935   0.085203  0.425720   2.402383       1.198377
# 3      0.776180   0.085203  1.408036   0.335272       1.134817
# 4      0.116259   0.085203  0.898091   0.439895       1.523683
# ...         ...        ...       ...        ...            ...
# 32555  0.849505   0.085203  0.639647   0.852050       0.745951
# 32556  0.103715   0.085203  0.335469   0.181506       0.420646
# 32557  1.423558   0.085203  0.358812   0.181506       0.420646
# 32558  1.216128   0.085203  0.110897   0.181506       0.420646
# 32559  0.983611   0.817787  0.929781   0.181506       0.420646
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.405890    0.790197      0.900122  0.393692  0.703036
# 1            1.733664    0.286803      0.277868  0.393692  0.703036
# ...

# %%
np.where(z>3)
# Out:
# (array([    3,     9,    10, ..., 32508, 32526, 32528], dtype=int64),
#  array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
z.iloc[3,13]
# Out:
# 5.355162649521019

# %%
z.iloc[9,12]
# Out:
# 3.204018209367117

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (27751, 15)

# %%
print("Data loss percentage is ",(df.shape[0]-df1.shape[0])/df.shape[0]*100)
# Out:
# Data loss percentage is  14.706786328989427

# %% [markdown]
# Data loss percentage is little high but removing outliers will help to improve the model performance.

# %%
df1.skew()
# Out:
# Age                0.484822
# Workclass          0.081802
# Fnlwgt             0.629037
# Education         -0.955723
# Education_num     -0.145695
# Marital_status    -0.045059
# Occupation         0.013496
# Relationship       0.753378
# Race              -2.587054
# Sex               -0.688876
# Capital_gain       4.928795
# Capital_loss      29.504415
# Hours_per_week    -0.358726
# Native_country    -5.411057
# Income             1.322128
# dtype: float64

# %%
df1['Capital_loss']=np.cbrt(df1['Capital_loss'])

# %%
df1.skew()
# Out:
# Age                0.484822
# Workclass          0.081802
# Fnlwgt             0.629037
# Education         -0.955723
# Education_num     -0.145695
# Marital_status    -0.045059
# Occupation         0.013496
# Relationship       0.753378
# Race              -2.587054
# Sex               -0.688876
# Capital_gain       4.928795
# Capital_loss      25.617854
# Hours_per_week    -0.358726
# Native_country    -5.411057
# Income             1.322128
# dtype: float64

# %%
df1['Capital_loss']=np.log1p(df1['Capital_loss'])

# %%
df1.skew()
# Out:
# Age                0.484822
# Workclass          0.081802
# Fnlwgt             0.629037
# Education         -0.955723
# Education_num     -0.145695
# Marital_status    -0.045059
# Occupation         0.013496
# Relationship       0.753378
# Race              -2.587054
# Sex               -0.688876
# Capital_gain       4.928795
# Capital_loss      24.937372
# Hours_per_week    -0.358726
# Native_country    -5.411057
# Income             1.322128
# dtype: float64

# %%
df1['Capital_loss']=np.cbrt(df1['Capital_loss'])

# %%
df1.skew()
# Out:
# Age                0.484822
# Workclass          0.081802
# Fnlwgt             0.629037
# Education         -0.955723
# Education_num     -0.145695
# Marital_status    -0.045059
# Occupation         0.013496
# Relationship       0.753378
# Race              -2.587054
# Sex               -0.688876
# Capital_gain       4.928795
# Capital_loss      24.793967
# Hours_per_week    -0.358726
# Native_country    -5.411057
# Income             1.322128
# dtype: float64

# %%
df1['Capital_gain']=np.cbrt(df1['Capital_gain'])

# %%
df1.skew()
# Out:
# Age                0.484822
# Workclass          0.081802
# Fnlwgt             0.629037
# Education         -0.955723
# Education_num     -0.145695
# Marital_status    -0.045059
# Occupation         0.013496
# Relationship       0.753378
# Race              -2.587054
# Sex               -0.688876
# Capital_gain       3.367311
# Capital_loss      24.793967
# Hours_per_week    -0.358726
# Native_country    -5.411057
# Income             1.322128
# dtype: float64

# %% [markdown]
# In 'capital_gain','capital_loss' column data is right skewed but skewness is not reducing so lets proceed with same skewness values.

# %%
df1.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.030416 -0.077342  -0.003984       0.044602
# Workclass       0.030416   1.000000 -0.026825   0.001559      -0.001812
# Fnlwgt         -0.077342  -0.026825  1.000000  -0.021254      -0.040000
# Education      -0.003984   0.001559 -0.021254   1.000000       0.346921
# Education_num   0.044602  -0.001812 -0.040000   0.346921       1.000000
# Marital_status -0.286029  -0.016039  0.029528  -0.037165      -0.058419
# Occupation     -0.001196   0.008068 -0.002084  -0.042268       0.072769
# Relationship   -0.270566  -0.057876  0.015059  -0.009515      -0.092841
# Race            0.020581   0.066438 -0.102369   0.026706       0.082854
# Sex             0.089817   0.069649  0.023150  -0.031634       0.003962
# Capital_gain    0.131788   0.004613 -0.005604   0.022779       0.133351
# Capital_loss    0.021919  -0.010464  0.001081  -0.000680       0.006682
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),cmap='BrBG',annot=True)
plt.show()

# %%
# Seperating features and target or label as x and y.
x=df1.drop('Income',axis=1)
y=df1['Income']

# %%
x.shape
# Out:
# (27751, 14)

# %%
y.shape
# Out:
# (27751,)

# %%
# Doing standard scaling to avoid the biasness.
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x.values),columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.884109   1.738685 -1.087657  -0.344860       1.212364
# 1     -0.011742  -0.077180  0.310200   0.171277      -0.440797
# 2      1.108072  -0.077180  0.511690  -2.409407      -1.267378
# 3     -0.086397  -0.077180  1.038373   0.429345       1.625655
# 4      0.809454  -0.077180 -0.275614  -1.119065      -2.093959
# ...         ...        ...       ...        ...            ...
# 27746 -0.832939  -0.077180  0.750213  -0.860997       0.799074
# 27747  0.137566  -0.077180 -0.337017   0.171277      -0.440797
# 27748  1.481343  -0.077180 -0.363044   0.171277      -0.440797
# 27749 -1.206211  -0.077180  0.160670   0.171277      -0.440797
# 27750  1.033417   0.830753  1.073706   0.171277      -0.440797
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.404580   -0.776933     -0.914099  0.344865  0.713231
# 1           -1.721355   -0.276482     -0.291332  0.344865  0.713231
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Feature']=x.columns
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#            Feature  VIF Values
# 0              Age    1.183643
# 1        Workclass    1.009760
# 2           Fnlwgt    1.029820
# 3        Education    1.147996
# 4    Education_num    1.221823
# 5   Marital_status    1.140927
# 6       Occupation    1.017174
# 7     Relationship    1.678447
# 8             Race    1.048742
# 9              Sex    1.553796
# 10    Capital_gain    1.042279
# 11    Capital_loss    1.003354
# 12  Hours_per_week    1.141030
# 13  Native_country    1.036231

# %% [markdown]
# Multicolinearity is present but its very less vif values and these values are acceptable range. So lets proceed with these values to train the model.

# %%
y.value_counts()  # Data imbalace is there so applying over sampling technique using smote method.
# Out:
# 0    21527
# 1     6224
# Name: Income, dtype: int64

# %%
# Doing over sampling by using smote method.
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    21527
# 1    21527
# Name: Income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
# Finding the best accuracy score in random state
maxacc=0
maxrs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    predict_lr=lr.predict(x_test)
    acc=accuracy_score(y_test,predict_lr)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print("Best accuracy score is ",maxacc,'at random state',maxrs)
# Out:
# Best accuracy score is  0.7762164673092556 at random state 351

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=maxrs,test_size=0.20)

# %%
from sklearn.model_selection import cross_val_score
LR=LogisticRegression()
LR.fit(x_train,y_train)
predict_LR=LR.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_LR))
print("Confusion matrix ",confusion_matrix(y_test,predict_LR))
print("Classification Report ",classification_report(y_test,predict_LR))
print("\n")
cvs=cross_val_score(LR,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_LR)-cvs.mean())
# Out:
# Accuracy score  0.7762164673092556
# Confusion matrix  [[3306 1008]
#  [ 919 3378]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77      4314
#            1       0.77      0.79      0.78      4297
#
#     accuracy                           0.78      8611
#    macro avg       0.78      0.78      0.78      8611
# weighted avg       0.78      0.78      0.78      8611
#
#
#
# Cross val score  [0.75984206 0.76506794 0.76181628 0.77203577 0.76840883]
# Cross val score mean  0.7654341750975948
# Difference between accuracy score and cross val score :  0.010782292211660827

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predict_RFC=RFC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_RFC))
print("Confusion matrix ",confusion_matrix(y_test,predict_RFC))
print("Classification Report ",classification_report(y_test,predict_RFC))
print("\n")
cvs=cross_val_score(RFC,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_RFC)-cvs.mean())
# Out:
# Accuracy score  0.9024503541981187
# Confusion matrix  [[3845  469]
#  [ 371 3926]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4314
#            1       0.89      0.91      0.90      4297
#
#     accuracy                           0.90      8611
#    macro avg       0.90      0.90      0.90      8611
# weighted avg       0.90      0.90      0.90      8611
#
#
#
# Cross val score  [0.82777842 0.88456625 0.92335385 0.93206364 0.92752613]
# Cross val score mean  0.8990576594154547
# Difference between accuracy score and cross val score :  0.0033926947826640186

# %%
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
predict_ETC=ETC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_ETC))
print("Confusion matrix ",confusion_matrix(y_test,predict_ETC))
print("Classification Report ",classification_report(y_test,predict_ETC))
print("\n")
cvs=cross_val_score(ETC,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_ETC)-cvs.mean())
# Out:
# Accuracy score  0.9115085355940077
# Confusion matrix  [[3821  493]
#  [ 269 4028]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      4314
#            1       0.89      0.94      0.91      4297
#
#     accuracy                           0.91      8611
#    macro avg       0.91      0.91      0.91      8611
# weighted avg       0.91      0.91      0.91      8611
#
#
#
# Cross val score  [0.86842411 0.89362443 0.92625711 0.93008942 0.92775842]
# Cross val score mean  0.909230699301369
# Difference between accuracy score and cross val score :  0.0022778362926386686

# %%
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)
predict_GBC=GBC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_GBC))
print("Confusion matrix ",confusion_matrix(y_test,predict_GBC))
print("Classification Report ",classification_report(y_test,predict_GBC))
print("\n")
cvs=cross_val_score(GBC,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_GBC)-cvs.mean())
# Out:
# Accuracy score  0.8741145047032864
# Confusion matrix  [[3636  678]
#  [ 406 3891]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      4314
#            1       0.85      0.91      0.88      4297
#
#     accuracy                           0.87      8611
#    macro avg       0.88      0.87      0.87      8611
# weighted avg       0.88      0.87      0.87      8611
#
#
#
# Cross val score  [0.81570085 0.85472071 0.87887586 0.88375334 0.87886179]
# Cross val score mean  0.8623825075319619
# Difference between accuracy score and cross val score :  0.01173199717132456

# %%
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predict_ABC=ABC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_ABC))
print("Confusion matrix ",confusion_matrix(y_test,predict_ABC))
print("Classification Report ",classification_report(y_test,predict_ABC))
print("\n")
cvs=cross_val_score(ABC,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_ABC)-cvs.mean())
# Out:
# Accuracy score  0.8535594007664615
# Confusion matrix  [[3573  741]
#  [ 520 3777]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      4314
#            1       0.84      0.88      0.86      4297
#
#     accuracy                           0.85      8611
#    macro avg       0.85      0.85      0.85      8611
# weighted avg       0.85      0.85      0.85      8611
#
#
#
# Cross val score  [0.80803623 0.84496574 0.86250145 0.86854024 0.8601626 ]
# Cross val score mean  0.848841253341113
# Difference between accuracy score and cross val score :  0.0047181474253484845

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
predict_BC=BC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_BC))
print("Confusion matrix ",confusion_matrix(y_test,predict_BC))
print("Classification Report ",classification_report(y_test,predict_BC))
print("\n")
cvs=cross_val_score(BC,x,y,cv=5)
print("Cross val score ",cvs)
print("Cross val score mean ",cvs.mean())
print("Difference between accuracy score and cross val score : ",accuracy_score(y_test,predict_BC)-cvs.mean())
# Out:
# Accuracy score  0.8916502148414819
# Confusion matrix  [[3885  429]
#  [ 504 3793]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      4314
#            1       0.90      0.88      0.89      4297
#
#     accuracy                           0.89      8611
#    macro avg       0.89      0.89      0.89      8611
# weighted avg       0.89      0.89      0.89      8611
#
#
#
# Cross val score  [0.79630705 0.86586924 0.91487632 0.92381837 0.9174216 ]
# Cross val score mean  0.8836585163535661
# Difference between accuracy score and cross val score :  0.00799169848791581

# %%
svc=SVC()
svc.fit(x_train,y_train)
predict_svc=svc.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_svc))
print("Confusion matrix ",confusion_matrix(y_test,predict_svc))
print("Classification Report ",classification_report(y_test,predict_svc))
# Out:
# Accuracy score  0.8383463012425967
# Confusion matrix  [[3362  952]
#  [ 440 3857]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83      4314
#            1       0.80      0.90      0.85      4297
#
#     accuracy                           0.84      8611
#    macro avg       0.84      0.84      0.84      8611
# weighted avg       0.84      0.84      0.84      8611

# %%
KNC=KNeighborsClassifier()
KNC.fit(x_train,y_train)
predict_KNC=KNC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_KNC))
print("Confusion matrix ",confusion_matrix(y_test,predict_KNC))
print("Classification Report ",classification_report(y_test,predict_KNC))
# Out:
# Accuracy score  0.8592497967715712
# Confusion matrix  [[3340  974]
#  [ 238 4059]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.85      4314
#            1       0.81      0.94      0.87      4297
#
#     accuracy                           0.86      8611
#    macro avg       0.87      0.86      0.86      8611
# weighted avg       0.87      0.86      0.86      8611

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
predict_DTC=DTC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,predict_DTC))
print("Confusion matrix ",confusion_matrix(y_test,predict_DTC))
print("Classification Report ",classification_report(y_test,predict_DTC))
# Out:
# Accuracy score  0.8586691441179887
# Confusion matrix  [[3686  628]
#  [ 589 3708]]
# Classification Report                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      4314
#            1       0.86      0.86      0.86      4297
#
#     accuracy                           0.86      8611
#    macro avg       0.86      0.86      0.86      8611
# weighted avg       0.86      0.86      0.86      8611

# %% [markdown]
# Out of all models Extra Trees Classifier is giving high accuracy. so lets consider this as best model and will improve the model performance by using hyperparameter tuning.

# %%
# Using hyperparameter tuning.
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['gini','entropy','log_loss']}
gscv=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
final_model=ExtraTreesClassifier(criterion='entropy')
final_model.fit(x_train,y_train)
predict_fin_modl=final_model.predict(x_test)
acc=accuracy_score(y_test,predict_fin_modl)
print(acc*100)
# Out:
# 91.03472302868424

# %%
y_pred_proba=final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)
plt.plot([0,1],[0,1],'k--')                               # Plotting AUC ROC Curve
plt.plot(fpr,tpr,label='Extra Trees Classifier') 
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
auc_score=roc_auc_score(y_test,final_model.predict(x_test))
print("Auc score : ",auc_score)
# Out:
# Auc score :  0.9104051149312374

# %%
import joblib
joblib.dump(final_model,'CensusIncome.pkl')    # Saving the model
# Out:
# ['CensusIncome.pkl']

# %%
model=joblib.load('CensusIncome.pkl')     # Reloading back the saved model

# %%
data=pd.DataFrame()
prediction=model.predict(x_test)
data['Original']=y_test
data['Predicted']=prediction
data
# Out:
#        Original  Predicted
# 35836         1          1
# 12524         0          1
# 10786         0          1
# 16380         1          1
# 34303         1          1
# ...         ...        ...
# 15192         0          0
# 6473          1          1
# 36165         1          1
# 11196         0          0
# 28592         1          1
#
# [8611 rows x 2 columns]

# %%
sns.stripplot(x=y_test,y=prediction,data=data)
# Out:
# <AxesSubplot:xlabel='Income'>

# %% [markdown]
# Successfully predicted the 'Income' target column or label with best accuracy score.

# %% [markdown]
# ## Thank You.
